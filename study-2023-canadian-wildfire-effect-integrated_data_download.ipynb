# %% [markdown]
# # Study 2023 Canadian Wildfires using TROPESS CrIS JPSS-1 Carbon Monoxide (CO) data products
#
# This code reads TROPESS CrIS JPSS-1 CO data products for June 2023 and June 2022 and make a monthly average data product and plot and compare them.
#
# Important note: Please "trust" this notebook before executing; this will prevent errors when writing output to your local directory.

# %%
import datetime
import contextlib

from pathlib import Path

import pandas as pd

import numpy as np
from netCDF4 import Dataset

import matplotlib.pyplot as plt

import imageio.v2 as imageio

from mpl_toolkits.basemap import Basemap

from scipy.interpolate import griddata
from scipy.spatial import cKDTree

# %% [markdown]
# Now we will download the first month of data from June 2023 to a local directory called 'data'. This download script is the podaac-data-downloader which requires credentials to authenticate with the NASA Earthdata Login. The download script has to first be installed in the same environment as the notebook. More details here: https://github.com/NASA-TROPESS/tutorials_notebooks/blob/main/data_subscriber_downloader.md

# %%
# !podaac-data-downloader -c TRPSYL2COCRS1FS -d data -p GES_DISC -sd 2023-06-01T00:00:00Z -ed 2023-06-30T23:23:59Z
# Out:
# [2023-10-20 10:16:24,138] {podaac_data_downloader.py:267} INFO - Found 30 total files to download
# [2023-10-20 10:16:29,283] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:29.283109 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230630_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:31,389] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:31.389196 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230629_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:34,634] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:34.634945 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230628_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:36,934] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:36.934128 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230627_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:38,884] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:38.884128 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230626_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:41,249] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:41.249791 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230625_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:42,939] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:42.939910 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230624_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:45,217] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:45.217956 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230623_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:47,898] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:47.898443 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230622_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:50,233] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:50.233933 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230621_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:52,152] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:52.152057 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230620_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:53,941] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:53.941380 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230619_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:55,762] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:55.762809 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230618_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:57,745] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:57.745316 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230617_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:16:59,353] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:16:59.353887 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230616_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:04,366] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:04.366191 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230615_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:07,023] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:07.023367 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230614_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:08,744] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:08.744664 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230613_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:10,407] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:10.407342 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230612_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:12,385] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:12.385217 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230611_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:15,385] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:15.385653 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230610_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:18,301] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:18.300983 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230609_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:20,271] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:20.271665 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230608_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:22,097] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:22.097631 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230607_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:23,992] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:23.992520 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230606_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:26,399] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:26.399443 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230605_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:29,080] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:29.080336 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230604_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:31,661] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:31.661097 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230603_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:33,866] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:33.866306 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230602_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:35,439] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:17:35.439208 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230601_MUSES_R1p20_FS_F0p6.nc
# [2023-10-20 10:17:35,439] {podaac_data_downloader.py:321} INFO - Downloaded Files: 30
# [2023-10-20 10:17:35,439] {podaac_data_downloader.py:322} INFO - Failed Files:     0
# [2023-10-20 10:17:35,439] {podaac_data_downloader.py:323} INFO - Skipped Files:    0
# [2023-10-20 10:17:35,913] {podaac_data_downloader.py:331} INFO - END

# %% [markdown]
# Let's read June 2023 daily data products and make a time series and make a monthly average of XCO (colum CO).
# The datasets should be already downloaded in the local directory ./data.
# Please refer to the tutorial about how to download TROPESS datasets from GES DISC.

# %%
# Specify date range
start_date = datetime.date(2023, 6, 1)
end_date = datetime.date(2023, 6, 30)

x_col_time_series_2023_june = []

# Loop through the date range and plot Carbon Monoxide for each day
for current_date in pd.date_range(start_date, end_date):
    # Open the netCDF file
    file_date = current_date.strftime("%Y%m%d")
    dataset = Dataset(f'./data/TROPESS_CrIS-JPSS1_L2_Summary_CO_{file_date}_MUSES_R1p20_FS_F0p6.nc', 'r')
    print("reading data from =", file_date)
    
    # Read the data from your variables
    latitude = dataset.variables['latitude'][:]
    longitude = dataset.variables['longitude'][:]
    x_col = dataset.variables['x_col'][:]

    dataset.close()

    # Filter the data for latitude 60S to 80N
    latitude_max = 80.0
    latitude_min = -60.0
    longitude_max = 180.0
    longitude_min = -180.0

    selection_only = np.where(
        (latitude > latitude_min) & (latitude < latitude_max) & 
        (longitude > longitude_min) &(longitude < longitude_max)
    )[0]

    latitude = latitude[selection_only]
    longitude = longitude[selection_only]
    x_col = x_col[selection_only]

    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    # Interpolate the data using griddata
    grid_x_col = griddata((latitude, longitude), x_col, (grid_lat, grid_lon), method='linear', rescale=True)

    # Find the distance to the nearest original point for each point in the interpolated grid
    tree = cKDTree(np.vstack((latitude, longitude)).T)
    dist, _ = tree.query(np.vstack((grid_lat.ravel(), grid_lon.ravel())).T)

    # Reshape the distance array to have the same shape as the x_col grid
    dist_grid = dist.reshape(grid_x_col.shape)

    # Mask the interpolated values that are too far from any original point
    max_distance_degrees = 3.0
    grid_x_col[dist_grid > max_distance_degrees] = np.nan
    
    # Make the time series of daily x_col for one month by appending each day's dataset. 
    x_col_time_series_2023_june.append(grid_x_col)

x_col_time_series_2023_june = np.array(x_col_time_series_2023_june)    
print(x_col_time_series_2023_june.shape)
x_col_month_mean_2023 = np.mean(x_col_time_series_2023_june, axis=0)
# Out:
# reading data from = 20230601
# reading data from = 20230602
# reading data from = 20230603
# reading data from = 20230604
# reading data from = 20230605
# reading data from = 20230606
# reading data from = 20230607
# reading data from = 20230608
# reading data from = 20230609
# reading data from = 20230610
# reading data from = 20230611
# reading data from = 20230612
# reading data from = 20230613
# reading data from = 20230614
# reading data from = 20230615
# reading data from = 20230616
# reading data from = 20230617
# reading data from = 20230618
# reading data from = 20230619
# reading data from = 20230620
# reading data from = 20230621
# reading data from = 20230622
# reading data from = 20230623
# reading data from = 20230624
# reading data from = 20230625
# reading data from = 20230626
# reading data from = 20230627
# reading data from = 20230628
# reading data from = 20230629
# reading data from = 20230630
# (30, 141, 361)

# %% [markdown]
# Let's make a global map of the June 2023 averaged XCO using Basemap.

# %%
    # Calculate width and height
    aspect_ratio = (longitude_max - longitude_min) / (latitude_max - latitude_min)
    w = 3600; h = w / aspect_ratio

    # Specify figure size (in inches)
    dpi = 300; 
    plt.figure(figsize=(w / dpi, h / dpi))  

    # Create a basemap instance
    m = Basemap(projection='cyl', resolution='l',
                llcrnrlat=-60, urcrnrlat=80,  # set latitude limits to -80 and 80
                llcrnrlon=-180, urcrnrlon=180)  # set longitude limits to -180 and -180

    m.drawmapboundary(fill_color='black')
    m.drawcoastlines(linewidth=0.3, color='white')
    m.drawcountries(linewidth=0.2, color='white')
    #m.drawstates(linewidth=0.2, color='white')


    # Draw parallels (latitude lines) and meridians (longitude lines)
    parallels = np.arange(-60., 81., 20.)
    m.drawparallels(parallels, labels=[True,False,False,False], linewidth=0.3)

    meridians = np.arange(-180., 181., 30.)
    m.drawmeridians(meridians, labels=[False,False,False,True], linewidth=0.3)
    
    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    
    # Plot the interpolated data using pcolormesh instead of scatter
    sc = m.pcolormesh(grid_lon, grid_lat, x_col_month_mean_2023, latlon=True, cmap='jet', alpha=0.7, vmin=60.0, vmax=200.0, shading='auto')
    
    
    # Add a colorbar
    cbar = m.colorbar(sc, location='bottom', pad="10%")
    cbar.set_label('Column-averaged dry-air mixing ratio of carbon monoxide from the surface to Top of Atmosphere (TOA), ppbv')

    # set plot title
    title_date = current_date.strftime("%b-%Y")
    title_min = np.nanmin(x_col_month_mean_2023)
    title_max = np.nanmax(x_col_month_mean_2023)
    plt.title(f'TROPESS - CrIS JPSS-1 - Carbon Monoxide Column (XCO) Month Average - June 2023')
    #\nMin: {title_min:.01f}, Max: {title_max:.01f} ppbv')

    # Save figure to PNG file
    plt.savefig(f'./images_average/TROPESS_Canadian-Fires_CrIS-JPSS-1_XCO_June_2023_month_average.png', dpi=dpi, bbox_inches='tight')

    plt.show()
    plt.close()

# %% [markdown]
# Now we will download the second month of data from June 2022 to a local directory called 'data'. This download script is the podaac-data-downloader which requires credentials to authenticate with the NASA Earthdata Login. The download script has to first be installed in the same environment as the notebook. More details here: https://github.com/NASA-TROPESS/tutorials_notebooks/blob/main/data_subscriber_downloader.md

# %%
# !podaac-data-downloader -c TRPSYL2COCRS1FS -d data -p GES_DISC -sd 2022-06-01T00:00:00Z -ed 2022-06-30T23:23:59Z
# Out:
# [2023-10-20 10:28:02,093] {podaac_data_downloader.py:267} INFO - Found 30 total files to download
# [2023-10-20 10:28:06,754] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:06.754834 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220630_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:08,623] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:08.623180 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220629_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:10,115] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:10.115541 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220628_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:13,206] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:13.206250 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220627_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:15,930] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:15.930769 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220626_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:17,806] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:17.806314 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220625_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:19,707] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:19.707536 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220624_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:21,348] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:21.348713 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220623_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:23,097] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:23.097239 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220622_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:25,057] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:25.057274 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220621_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:28,494] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:28.494064 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220620_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:31,101] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:31.101573 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220619_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:32,945] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:32.945345 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220618_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:34,588] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:34.588310 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220617_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:36,611] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:36.611677 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220616_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:38,352] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:38.352426 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220615_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:40,010] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:40.010754 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220614_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:43,064] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:43.064076 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220613_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:45,223] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:45.223764 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220612_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:46,834] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:46.834787 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220611_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:48,839] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:48.839611 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220610_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:50,790] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:50.790137 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220609_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:52,320] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:52.320364 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220608_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:53,931] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:53.931022 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220607_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:58,157] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:58.157745 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220606_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:28:59,938] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:28:59.938147 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220605_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:29:01,680] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:29:01.680597 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220604_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:29:03,458] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:29:03.458950 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220603_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:29:05,009] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:29:05.009125 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220602_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:29:06,553] {podaac_data_downloader.py:310} INFO - 2023-10-20 10:29:06.553435 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220601_MUSES_R1p17_FS_F0p6.nc
# [2023-10-20 10:29:06,553] {podaac_data_downloader.py:321} INFO - Downloaded Files: 30
# [2023-10-20 10:29:06,553] {podaac_data_downloader.py:322} INFO - Failed Files:     0
# [2023-10-20 10:29:06,553] {podaac_data_downloader.py:323} INFO - Skipped Files:    0
# [2023-10-20 10:29:06,722] {podaac_data_downloader.py:331} INFO - END

# %% [markdown]
# Let's read June 2022 daily data products and make a time series and make a monthly average of XCO (colum CO).
# The datasets should be already downloaded in the local directory ./data.
# Please refer to the tutorial about how to download TROPESS datasets from GES DISC.

# %%
# Specify date range
start_date = datetime.date(2022, 6, 1)
end_date = datetime.date(2022, 6, 30)

x_col_time_series_2022_june = []

# Loop through the date range and plot Carbon Monoxide for each day
for current_date in pd.date_range(start_date, end_date):
    # Open the netCDF file
    file_date = current_date.strftime("%Y%m%d")
    dataset = Dataset(f'./data/TROPESS_CrIS-JPSS1_L2_Summary_CO_{file_date}_MUSES_R1p17_FS_F0p6.nc', 'r')
    print("reading data from =", file_date)
    
    # Read the data from your variables
    latitude = dataset.variables['latitude'][:]
    longitude = dataset.variables['longitude'][:]
    x_col = dataset.variables['x_col'][:]

    dataset.close()

    # Filter the data for latitude 80S to 80N
    latitude_max = 80.0
    latitude_min = -60.0
    longitude_max = 180.0
    longitude_min = -180.0

    selection_only = np.where(
        (latitude > latitude_min) & (latitude < latitude_max) & 
        (longitude > longitude_min) &(longitude < longitude_max)
    )[0]

    latitude = latitude[selection_only]
    longitude = longitude[selection_only]
    x_col = x_col[selection_only]


    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    # Interpolate the data using griddata
    grid_x_col = griddata((latitude, longitude), x_col, (grid_lat, grid_lon), method='linear', rescale=True)

    # Find the distance to the nearest original point for each point in the interpolated grid
    tree = cKDTree(np.vstack((latitude, longitude)).T)
    dist, _ = tree.query(np.vstack((grid_lat.ravel(), grid_lon.ravel())).T)

    # Reshape the distance array to have the same shape as the x_col grid
    dist_grid = dist.reshape(grid_x_col.shape)

    # Mask the interpolated values that are too far from any original point
    max_distance_degrees = 3.0
    grid_x_col[dist_grid > max_distance_degrees] = np.nan
    
    x_col_time_series_2022_june.append(grid_x_col)
    

x_col_time_series_2022_june = np.array(x_col_time_series_2022_june)    
print(x_col_time_series_2022_june.shape)
x_col_month_mean_2022 = np.mean(x_col_time_series_2022_june, axis=0)
print("X_col_month_mean_shape = ", x_col_month_mean_2022.shape)
# Out:
# reading data from = 20220601
# reading data from = 20220602
# reading data from = 20220603
# reading data from = 20220604
# reading data from = 20220605
# reading data from = 20220606
# reading data from = 20220607
# reading data from = 20220608
# reading data from = 20220609
# reading data from = 20220610
# reading data from = 20220611
# reading data from = 20220612
# reading data from = 20220613
# reading data from = 20220614
# reading data from = 20220615
# reading data from = 20220616
# reading data from = 20220617
# reading data from = 20220618
# reading data from = 20220619
# reading data from = 20220620
# reading data from = 20220621
# reading data from = 20220622
# reading data from = 20220623
# reading data from = 20220624
# reading data from = 20220625
# reading data from = 20220626
# reading data from = 20220627
# reading data from = 20220628
# reading data from = 20220629
# reading data from = 20220630
# (30, 141, 361)
# X_col_month_mean_shape =  (141, 361)

# %% [markdown]
# Let's make a global map of the June 2022 averaged XCO using Basemap.

# %%
    # Calculate width and height
    aspect_ratio = (longitude_max - longitude_min) / (latitude_max - latitude_min)
    w = 3600; h = w / aspect_ratio

    # Specify figure size (in inches)
    dpi = 300; 
    plt.figure(figsize=(w / dpi, h / dpi))  

    # Create a basemap instance
    m = Basemap(projection='cyl', resolution='l',
                llcrnrlat=-60, urcrnrlat=80,  # set latitude limits to -80 and 80
                llcrnrlon=-180, urcrnrlon=180)  # set longitude limits to -180 and -180

    m.drawmapboundary(fill_color='black')
    m.drawcoastlines(linewidth=0.3, color='white')
    m.drawcountries(linewidth=0.2, color='white')
    #m.drawstates(linewidth=0.2, color='white')


    # Draw parallels (latitude lines) and meridians (longitude lines)
    parallels = np.arange(-60., 81., 20.)
    m.drawparallels(parallels, labels=[True,False,False,False], linewidth=0.3)

    meridians = np.arange(-180., 181., 30.)
    m.drawmeridians(meridians, labels=[False,False,False,True], linewidth=0.3)
    
    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    
    # Plot the interpolated data using pcolormesh instead of scatter
    sc = m.pcolormesh(grid_lon, grid_lat, x_col_month_mean_2022, latlon=True, cmap='jet', alpha=0.7, vmin=60.0, vmax=200.0, shading='auto')

    
    # Add a colorbar
    cbar = m.colorbar(sc, location='bottom', pad="10%")
    cbar.set_label('Column-averaged dry-air mixing ratio of carbon monoxide from the surface to Top of Atmosphere (TOA), ppbv')

    # set plot title
    title_date = current_date.strftime("%b-%Y")
    title_min = np.nanmin(x_col_month_mean_2022)
    title_max = np.nanmax(x_col_month_mean_2022)
    plt.title(f'TROPESS - CrIS JPSS-1 - Carbon Monoxide Column (XCO) Month Average - June 2022')
    #\nMin: {title_min:.01f}, Max: {title_max:.01f} ppbv')

    # Save figure to PNG file
    plt.savefig(f'./images_average/TROPESS_Canadian-Fires_CrIS-JPSS-1_XCO_June_2022_month_average.png', dpi=dpi, bbox_inches='tight')

    plt.show()
    plt.close()

# %% [markdown]
# Let's get the difference between June 2023 XCO and June 2022 XCO and plot the difference in a global map.

# %%
    x_col_diff_month_average = x_col_month_mean_2023 - x_col_month_mean_2022
    #print (x_col_diff_month_average.shape)
 
    # Calculate width and height
    aspect_ratio = (longitude_max - longitude_min) / (latitude_max - latitude_min)
    w = 3600; h = w / aspect_ratio

    # Specify figure size (in inches)
    dpi = 300; 
    plt.figure(figsize=(w / dpi, h / dpi))  

    # Create a basemap instance
    m = Basemap(projection='cyl', resolution='l',
                llcrnrlat=-60, urcrnrlat=80,  # set latitude limits to -80 and 80
                llcrnrlon=-180, urcrnrlon=180)  # set longitude limits to -180 and -180

    m.drawmapboundary(fill_color='black')
    m.drawcoastlines(linewidth=0.3, color='white')
    m.drawcountries(linewidth=0.2, color='white')
    #m.drawstates(linewidth=0.2, color='white')


    # Draw parallels (latitude lines) and meridians (longitude lines)
    parallels = np.arange(-60., 81., 20.)
    m.drawparallels(parallels, labels=[True,False,False,False], linewidth=0.3)

    meridians = np.arange(-180., 181., 30.)
    m.drawmeridians(meridians, labels=[False,False,False,True], linewidth=0.3)
    
    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the map
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    
    # Plot the difference data using pcolormesh instead of scatter
    sc = m.pcolormesh(grid_lon, grid_lat, x_col_diff_month_average, latlon=True, cmap='seismic', alpha=0.8, vmin=-60, vmax=60.0, shading='auto')

    # Add a colorbar
    cbar = m.colorbar(sc, location='bottom', pad="10%")
    cbar.set_label('Column-averaged dry-air mixing ratio of carbon monoxide from the surface to Top of Atmosphere (TOA), ppbv')

    # set plot title
    #title_date = current_date.strftime("%b-%Y")
    title_min = np.nanmin(x_col_diff_month_average)
    title_max = np.nanmax(x_col_diff_month_average)
    plt.title(f'TROPESS - CrIS JPSS-1 - Carbon Monoxide Column (XCO) June Difference (2023 - 2022)')
    #' \nMin: {title_min:.01f}, Max: {title_max:.01f} ppbv')

    # Save figure to PNG file
    plt.savefig(f'./images_average/TROPESS_Canadian-Fires_CrIS-JPSS-1_XCO_2023_2022_June_month_diff.png', dpi=dpi, bbox_inches='tight')

    plt.show()
    plt.close()

# %% [markdown]
# Let's calculate the average difference of xco in the Northeast part of North America (latitude = [40,60] and longitude [-90,-60]].)

# %%
    latitude_min=40
    latitude_max=60
    longitude_min=-90
    longitude_max=-60
    
    small_selection = np.where(
        (grid_lat > latitude_min) & (grid_lat < latitude_max) & 
        (grid_lon > longitude_min) &(grid_lon < longitude_max)
    )

    #print (small_selection)
    grid_lat_small = grid_lat[small_selection]
    grid_lon_small = grid_lon[small_selection]
    x_col_diff_small = x_col_diff_month_average[small_selection]
    
    
    x_col_diff_mean = x_col_diff_small.mean()
    print("Northeast America XCO increase from 2022 June to 2023 June = ", "{0:.2f}".format(x_col_diff_mean), 'ppbv')
# Out:
# Northeast America XCO increase from 2022 June to 2023 June =  20.44 ppbv

# %% [markdown]
# Let's write the monthly average data and difference data in a NetCDF file for future use.

# %%
import numpy as np
import datetime
from netCDF4 import Dataset,num2date,date2num


longitude_1D = np.arange(-180,181,1.0)
latitude_1D = np.arange(-60,81,1.0)

#print('length of latitude =', len(latitude_1D))
#print('length of longitude =', len(longitude_1D))

ncout = Dataset('TROPESS_CRIS_JPSS1_2022_2023_June_XCO.nc', mode='w', format='NETCDF4_CLASSIC')

ncout.createDimension('latitude', len(latitude_1D))
ncout.createDimension('longitude', len(longitude_1D))

lonvar = ncout.createVariable('longitude','float32',('longitude'))
lonvar[:] = longitude_1D

latvar = ncout.createVariable('latitude','float32',('latitude'))
latvar[:] = latitude_1D

myvar = ncout.createVariable('xco_2022_June','float32',('latitude','longitude'))
myvar.setncattr('units','ppbv')
myvar[:] = x_col_month_mean_2022;

myvar = ncout.createVariable('xco_2023_June','float32',('latitude','longitude'))
myvar.setncattr('units','ppbv')
myvar[:] = x_col_month_mean_2023;

myvar = ncout.createVariable('xco_diff','float32',('latitude','longitude'))
myvar.setncattr('units','ppbv')
myvar[:] = x_col_diff_month_average;
ncout.close();
